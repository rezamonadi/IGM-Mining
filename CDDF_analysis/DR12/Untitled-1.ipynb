# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
cddf_all = np.loadtxt('cddf_all.txt')
cddf_all

print(cddf_all[0])

plt.plot(cddf_all[0])
# Out:
# [13.04166667 13.125      13.20833333 13.29166667 13.375      13.45833333
#  13.54166667 13.625      13.70833333 13.79166667 13.875      13.95833333
#  14.04166667 14.125      14.20833333 14.29166667 14.375      14.45833333
#  14.54166667 14.625      14.70833333 14.79166667 14.875      14.95833333
#  15.04166667 15.125      15.20833333 15.29166667 15.375      15.45833333]

# %%
dndx = np.loadtxt('dndx_all.txt')
dndx1 = dndx[0]
print(dndx1)
plt.plot(dndx1, cddf_all)
# Out:
# [2.08333333 2.25       2.41666667 2.58333333 2.75       2.91666667
#  3.08333333 3.25       3.41666667 3.58333333 3.75       3.91666667
#  4.08333333 4.25       4.41666667 4.58333333 4.75       4.91666667]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_23117/1856108068.py in <module>
#       2 dndx1 = dndx[0]
#       3 print(dndx1)
# ----> 4 plt.plot(dndx1, cddf_all)
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2767 @_copy_docstring_and_deprecators(Axes.plot)
#    2768 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2769     return gca().plot(
#    2770         *args, scalex=scalex, scaley=scaley,
#    2771         **({"data": data} if data is not None else {}), **kwargs)
#
# ...
