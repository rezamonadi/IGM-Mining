# %%
from astropy.io import fits
import numpy as np
from collections import Counter
hdul= fits.open('data/C4_catalogs/Cooksey_C4_cat/distfiles/sdss_civrate_hyb_all_update1.fit')   

data = hdul[1].data
Notes = data['Notes']

allStr=[]
for i in range(len(Notes)):
    allStr.append(Notes[i])

# %%
Counter(allStr).most_common()
# Out:
# [('', 25093),
#  (b'[K] check', 484),
#  (b'[K] ghost emission', 467),
#  (b'[K] bad conti', 345),
#  (b'bad conti', 261),
#  (b'[K] SiIV', 192),
#  (b'[K] sky lines', 114),
#  (b'contin', 114),
#  (b'[K] FeII', 108),
#  (b'KLC was 0; RAS 2; let neighbor represent; KLC now 1', 77),
#  (b'[K] SiII', 59),
#  (b'[K] AlII', 55),
#  (b'[K] MgII', 52),
#  (b'[K] SiII 1526', 52),
#  (b'[J] contin', 47),
#  (b'MgII', 46),
#  (b'KLC was 0; JMO 2; let neighbor represent; KLC now 1', 41),
#  (b'no HI', 40),
#  (b'[K] check (was RTG=0)', 40),
#  (b'FeII', 31),
#  (b'SiIV', 28),
#  (b'No HI', 25),
#  (b'HI', 25),
#  (b'[J] SiIV', 25),
#  (b'conti', 24),
#  (b'[J] FeII', 21),
#  (b'KLC was 1; JMO 2; nothing else to call it; KLC now 2', 21),
#  (b'[K] check (was RTG=3)', 18),
#  (b'MgII?', 17),
#  (b'KLC was 1; RAS 2; nothing else to call it; KLC now 2', 16),
#  (b'[J] HI', 14),
#  (b'see prev', 14),
#  (b'[K] check (complex)', 14),
#  (b'[K] ghost emission; check', 13),
#  (b'KLC was 0; RAS 3; let neighbor represent; KLC now 1', 13),
#  (b'[K] ghost emission; bad conti', 12),
#  (b'has HI', 12),
#  (b'[K] CII', 12),
#  (b'SiII', 12),
#  (b'[K] bounds?', 11),
#  (b'[K] CIV', 11),
#  (b'BAL?', 11),
#  (b'blend?', 11),
#  (b'[K] SiII blend 1550', 11),
#  (b'FeII 1608', 10),
#  (b'[J] SiII', 10),
#  (b'conti fail', 10),
#  (b'[K] incl. red comp.?', 9),
#  (b'[K] AlIII', 9),
#  (b'[K] MgI', 9),
#  (b'CII', 9),
#  (b'[K] SiIV; SiIV', 9),
#  (b'[K] broad line to red should be candidate', 9),
#  (b'SiII 1526', 9),
#  (b'blend', 9),
#  (b'[J] blend?', 8),
#  (b'AlII 1670', 8),
#  (b'[K] broad line to blue should be candidate', 8),
#  (b'[K] ghost emission; [J] contin', 8),
#  (b'[K] SiIV 1402 blend 1550', 8),
#  (b'[K] broad red line should be candidate', 8),
#  (b'good HI', 7),
#  (b'[K] incl. blue comp.?', 7),
#  (b'[K] SiII 1526?', 7),
#  (b'[K] bad conti; check', 7),
#  (b'[J] see prev', 7),
#  (b'KLC was 0; JMO 2; let match duplicate; KLC now 2', 7),
#  (b'[K] SiII blend 1548', 7),
#  (b'confirmed MgII', 7),
#  (b'SiIV 1393', 7),
#  (b'[K] check rating consistent', 7),
#  (b'contin high', 6),
#  (b'[K] sky lines; check', 6),
#  (b'FeII 2382', 6),
#  (b'SiIV blend', 6),
#  (b'weird', 6),
#  (b'[K] broad blue line should be candidate', 6),
#  (b'[J] contin high', 5),
#  (b'AlII', 5),
#  (b'[K] MgII?', 5),
#  (b'[K] SiIV twice', 5),
#  (b'BAL', 5),
#  (b'[K] ghost emission; ghost emission', 5),
#  (b'[J] sky?', 5),
#  (b'[K] FeII; check (was RTG=3)', 5),
#  (b'contin; KLC was 0; JMO 2; let neighbor represent; KLC now 1', 5),
#  (b'[K] check; ghost emission', 5),
#  (b'[K] bad conti; ghost emission', 5),
#  (b'FeII 2344', 5),
#  (b'[K] ghost emission?', 4),
#  (b'[K] SiIV, CIV', 4),
#  (b'[K] FeII, MnII', 4),
#  (b'[K] SiIV; CIV', 4),
#  (b'[K] FeII 1608 blend 1548', 4),
#  (b'Contin', 4),
#  (b'KLC was 0; JMO 2; match duplicate; KLC now 2', 4),
#  (b'[K] CIV to red', 4),
#  (b'mgII', 4),
#  (b'[K] check (was RTG=0); KLC was 1; RAS 2; nothing else to call it; KLC now 2',
#   4),
#  (b'FeII 2586', 4),
#  (b'questionable conti', 4),
#  (b'Confirmed by MgII', 4),
#  (b'CII 1334', 4),
#  (b'[K] CIV; CIV', 4),
#  (b'noise?', 3),
#  (b'KLC orig 1; RAS 2; blended with real system; KLC 2 now', 3),
#  (b'[K] ghost emission; bounds?', 3),
#  (b'DLA', 3),
#  (b'mgII?', 3),
#  (b'big HI', 3),
#  (b'[K] SiII to red', 3),
#  (b'[K] bad conti; check (was RTG=3)', 3),
#  (b'[K] ghost emission; sky lines', 3),
#  (b'noise spike?', 3),
#  (b'shifted to left', 3),
#  (b'FeII blend', 3),
#  (b'[K] bad conti; sky lines', 3),
#  (b'[J] AlII', 3),
#  (b'[K] CaII?', 3),
#  (b'[K] SiIV 1402 blend 1548', 3),
#  (b'[K] ghost emission; AlII', 3),
#  (b'[K] MgI blend 1550', 3),
#  (b'[J] OI', 3),
#  (b'[K] SiII blend 1548?', 3),
#  (b'SiIV?', 3),
#  (b'[K] FeII blend 1548', 3),
#  (b'[K] broad line to red should be candidate; check', 3),
#  (b'blend?; KLC was 0; JMO 2; let neighbor represent; KLC now 1', 3),
#  (b'sky issues', 3),
#  (b'[K] SiII blend 1548?; check', 3),
#  (b'[K] ghost emission; FeII', 3),
#  (b'outflow?', 3),
#  (b'[K] FeII; SiII', 3),
#  (b'[K] broad line to blue should be candidate; check', 3),
#  (b'ejecta', 3),
#  (b'confirmed by FeII, MgII', 3),
#  (b'KLC was 0; RAS 2; match duplicate; KLC now 2', 3),
#  (b'Confirmed MgII', 3),
#  (b'[K] broad blue line should be candidate (real)', 3),
#  (b'AlIII doublet', 3),
#  (b'ejected?', 3),
#  (b'[K] check; broad line to red should be candidate', 3),
#  (b'SiIV 1402', 3),
#  (b'SiII 1526?', 3),
#  (b'noise', 2),
#  (b'[K] SiIV blended', 2),
#  (b'[K] bad conti; SiII 1526', 2),
#  (b'v. low snr, bad skysub', 2),
#  (b'[J] shifted to right', 2),
#  (b'MgII to the right', 2),
#  (b'KLC orig 0; JMO 2; blended with real system; KLC now 2', 2),
#  (b'[J] abs is to the right', 2),
#  (b'noise spike', 2),
#  (b'[K] SiIV and SiII 1526', 2),
#  (b'[K] CIV; SiII', 2),
#  (b'[J] real abs is to the right', 2),
#  (b'shifted', 2),
#  (b'[J] blend w/ previous', 2),
#  (b'conti high', 2),
#  (b'AlII1670', 2),
#  (b'[K] SiII; check', 2),
#  (b'[K] DLA ion', 2),
#  (b'KLC was 1; RAS 2; nothing else to call it; KLC 2 now', 2),
#  (b'[K] FeII; check', 2),
#  (b'[J] see previous', 2),
#  (b'[K] check; sky lines', 2),
#  (b'Has HI', 2),
#  (b'[K] FeII; [J] FeII', 2),
#  (b'mgii', 2),
#  (b'bal?', 2),
#  (b'[K] FeII, AlII', 2),
#  (b'[J] good HI', 2),
#  (b'[K] bad conti; bad conti', 2),
#  (b'[J] real abs to the left', 2),
#  (b'sky', 2),
#  (b'[K] SiIV, FeII', 2),
#  (b'[K] SiII; SiII', 2),
#  (b'[K] sky lines; MgII', 2),
#  (b'[K] FeII; AlII', 2),
#  (b'[J] contin FeII', 2),
#  (b'bal outflow?', 2),
#  (b'[K] CII; check (was RTG=3)', 2),
#  (b'AlIII', 2),
#  (b'[K] What is this?', 2),
#  (b'contion', 2),
#  (b'[J] feII', 2),
#  (b'[K] AlII blend 1550?', 2),
#  (b'[J] no way to know', 2),
#  (b'[K] FeII; FeII', 2),
#  (b'[K] SiII blend 1550?', 2),
#  (b'HI; KLC was 0; JMO 2; let neighbor represent; KLC now 1', 2),
#  (b'KLC was 1; RAS 2; for lack of anything else to call it; KLC now 2', 2),
#  (b'KLC was 0; JMO 3; let neighbor represent; KLC now 1', 2),
#  (b'[K] FeII 1608 blend 1550', 2),
#  (b'[K] MgII blend 1550', 2),
#  (b'[J] MgII', 2),
#  (b'[K] broad line to blue should be candidate (real)', 2),
#  (b'[K] ghost emission?; [J] real abs to right and left', 2),
#  (b'[K] MgII blend 1548', 2),
#  (b'[K] SiIV 1402 blend 1550; FeII', 2),
#  (b'real abs to left', 2),
#  (b'real abs to right', 2),
#  (b'[K] SiII blend', 2),
#  (b'[K] ghost emission; [J] see prev', 2),
#  (b'KLC was 0; JMO 2; let neighbor represent; KLC now 2', 2),
#  (b'[K] SiIV; AlII', 2),
#  (b'CaII at z = 0.1?', 2),
#  (b'KLC was 0; RAS @; let neighbor represent; KLC now 1', 2),
#  (b'Ejected', 2),
#  (b'noHI', 2),
#  (b'[K] broad line to red should be candidate (real)', 2),
#  (b'[K] SiIV, AlII', 2),
#  (b'[K] FeII; check (was RTG=3); KLC was 0; JMO 2; nothing else to call it; KLC now 2',
#   2),
#  (b'Confirmed by FeII and MgII', 2),
#  (b'Confirmed by SiIV', 2),
#  (b'CII from a DLA', 2),
#  (b'SiII 1526 for a DLA', 2),
#  (b'No HI?', 2),
#  (b'KLC was 0; RAS 2; match overlap/duplicate; KLC now 2', 2),
#  (b'KLC was 1; RAS 2; let neighbor represent; KLC now 1', 2),
#  (b'terrible conti', 2),
#  (b'[K] SiIV; bad conti', 2),
#  (b'[K] SiIV?', 2),
#  (b'Blend with SiIV', 2),
#  (b'Confirmed SiIV', 2),
#  (b'[K] FeII; CIV', 2),
#  (b'MgII confirms', 2),
#  (b'blend with SiIV', 2),
#  (b'FeII 2374', 2),
#  (b'bad data?', 2),
#  (b'[K] check (was RTG=3) contin', 2),
#  (b'KLC ws 0; RAS 2; let neighbor represent; KLC now 1', 2),
#  (b'SiII 1526 blend', 2),
#  (b'[K] check (was RTG=0) contin', 2),
#  (b'SiIV!', 2),
#  (b'[K] FeII; SiIV', 2),
#  (b'[K] SiIV 1393 blend 1548', 2),
#  (b'blend with FeII 1608', 2),
#  (b"dunno what this is but it's not a normal CIV.  BAL?", 2),
#  (b'contin.  ejected?', 2),
#  (b'[K] check consistent rating', 2),
#  (b'[K] SiII blend 1550; check', 2),
#  (b'see prev; KLC was 1; JMO 2; let neighbor represent; KLC still 1', 2),
#  (b'contin; KLC was 1; JMO 2; let neighbor represent; KLC still 1', 2),
#  (b'[K] broad blue line should be candidate?', 2),
#  (b'bad conti?', 2),
#  (b'bad conti, no hi', 2),
#  (b'MgII blend', 2),
#  (b'noisy/conti', 2),
#  (b'FeII 1608, double component', 2),
#  (b'AlIII blend', 2),
#  (b'[K] ghost emission; check (complex)', 2),
#  (b'OI/SiII', 2),
#  (b'conti?', 2),
#  (b'HUGE!', 2),
#  (b'[K] SiII; CIV', 2),
#  (b'SiII 1526 + ?', 2),
#  (b'I suspect blend or noise spice contaminant on 1548 line.', 1),
#  (b'mgII 2796 line tagged as 1550 line incorrectly', 1),
#  (b'I suspect bad sky sub effecting 1548 line?  Possibly real.', 1),
#  (b'[J] shifted line bad conti', 1),
#  (b'this was same abs as previous.  I shifted the previous one to this, so throw out the double count!',
#   1),
#  (b'[J] FeII and SiIV seem to help the case for it being real.', 1),
#  (b"contin spike at 1550, but I think it's not real CIV", 1),
#  (b'KLC orig 1, RAS 2, nothing else to be, KLC 2 now', 1),
#  (b'[J] looks ok, but very near edge.  MAtching MgII!', 1),
#  (b"I think it's MgII", 1),
#  (b'contin high at 1550, probably not real abs', 1),
#  (b'[J] mgII says likely', 1),
#  (b'booming SiIV', 1),
#  (b'contam affected by nearby abs, but CIV looks real', 1),
#  (b'KLC orig 1; JMO 2; FeII surrounds and putative 1548 is SiIV 1393; KLC 1 still',
#   1),
#  (b'One is SiIV from the intrinsic system', 1),
#  (b'[K] SiII 1526; [J] contamination on 1548, shifted bounds', 1),
#  (b'higher z system', 1),
#  (b'good HI; KLC orig 0; JMO 2; near real system; KLC 2 now', 1),
#  (b'SiIV says yes', 1),
#  (b'contin a bit high at 1550', 1),
#  (b'some SiII 1526', 1),
#  (b'[J] on skyline, probably ok', 1),
#  (b'[J] noise spike may be messing up 1548?  bad conti too...', 1),
#  (b'just seems weird', 1),
#  (b'other metals say yes', 1),
#  (b'I trust the left pair more.', 1),
#  (b'contin high at 1550', 1),
#  (b'contin high, but plausable abs', 1),
#  (b'other metals say yes!', 1),
#  (b'cntin high in noisy part', 1),
#  (b'[J] SiIV from BAL', 1),
#  (b'[J] 1550 is actually FeII from lower z MgII sys - not buying FeII, fosc not right?',
#   1),
#  (b'v. close to serious sky sub issues', 1),
#  (b'conti; KLC orig 2; RAS 1; bad conti and questional profile; KLC 1 now', 1),
#  (b"conti low; KLC orig 0; JMO 2; it's intrinsic but KLC 2 now", 1),
#  (b'[K] include blue wing?', 1),
#  (b'kLC orig 2; RAS 0; it is crazy bad; KLC 1 now', 1),
#  (b'v low snr, bad skysub', 1),
#  (b'[J] 1548 line plausible, but 1550 in poor skysub', 1),
#  (b'1548 line is acually 1550 line of neigbor to the left', 1),
#  (b"it's real, and I can't find anything else", 1),
#  (b'[J] contin a bit ok, otherwise ok', 1),
#  (b'contin high, not likely', 1),
#  (b'[K] CII?; check', 1),
#  (b'Mg II hints at 2 absrbers, deltav ~ 500kms', 1),
#  (b'KLC orig 0; RAS 2; blended with real system; KLC 2 now', 1),
#  (b'[J] SiIV indicates likely Also AlII / FeII', 1),
#  (b'[J] noise? looks otherwise ok.  Ejected?  HI is weak', 1),
#  (b'I think there are 2 abs sys nearby, but not at this z', 1),
#  (b'[J] shifted to right, blended abs?  z is off.', 1),
#  (b'[J] metal from DLA', 1),
#  (b'KLC orig 1; RAS 2; blended with real sytem; KLC 2 now', 1),
#  (b'conti; KLC orig 2; RAS 1; totally; KLC 1 now', 1),
#  (b'[K] SiII 1526 - the 1526 is in the middle only?', 1),
#  (b'KLC orig 1; RAS 2; good line to red is SiII; KLC 1 still', 1),
#  (b'Big HI, possible 1526.  Smoke = fire?', 1),
#  (b"KLC orig 1; RAS 2; that's bad; KLC still 1", 1),
#  (b'[K] sky lines; must shift bounds', 1),
#  (b'very ratty spectrum', 1),
#  (b'real abs on either side', 1),
#  (b'shifted to right; KLC orig 0; JMO 2; actually SiIV 1392 w/ CIV; KLC still 0',
#   1),
#  (b'[K] SiII is AlIII', 1),
#  (b'[K] line to red should be candidate (real!)', 1),
#  (b'bad conti, shitty data', 1),
#  (b'[K] bad conti; bounds?', 1),
#  (b'KLC orig 1; RAS 3; blend with real system; KLC now 3', 1),
#  (b'[J] contin wrong - its the BAL', 1),
#  (b'KLC orig 2; RAS 1; probably b/c intrinsic; mask out sightline; KLC 2 still',
#   1),
#  (b'KLC orig 2; RAS 1; probably b/c intrinsic; exclude sightline; KLC still 2',
#   1),
#  (b'[K] SiII 1526 of neighbor; [J] part of BAL?', 1),
#  (b"KLC orig 0; JMO 2; agree it's a blended thing; KLC 2 now", 1),
#  (b'[K] SiIV; check', 1),
#  (b"I think there is a CIV there, not the one flagged, but it's the best one found.",
#   1),
#  (b'[J] contin riding high', 1),
#  (b'[K] SiIV two ways', 1),
#  (b'[J] real abs is to right, agreed, so flag it', 1),
#  (b"[J] real abs is to left - I agree, but it's not ID'ed so I'll use this one.",
#   1),
#  (b'No others?', 1),
#  (b'SiII 1526 - Yes, 1526', 1),
#  (b'[K] ghost emission nearby', 1),
#  (b'[J] noise spike in the 1548, but abs lines up w/ HI.  Bounds off?', 1),
#  (b'[J] continuum too high / bad conti', 1),
#  (b'[J] continuum a bit high', 1),
#  (b'[J] abs is to the right, not this - agreed', 1),
#  (b'[K] SiII; ghost emission', 1),
#  (b'MgII as well at this z', 1),
#  (b'[K] ghost emission; [J] contin too high conti fail', 1),
#  (b'[K] SiIV; sky lines', 1),
#  (b'KLC orig 1; RAS 2; morely like MgII; KLC now 0', 1),
#  (b'data error', 1),
#  (b'[K] MgII; CIV', 1),
#  (b'data error nearby', 1),
#  (b'MgII and CIV systems close by', 1),
#  (b'the 1548 is actually the 1550 of a different', 1),
#  (b'no HI, FeII 2344', 1),
#  (b'[K] SiII 1526 is red line', 1),
#  (b'[K] intrinsic CIV fit out?', 1),
#  (b'[K] rest is real', 1),
#  (b'[K] FeII, CIV', 1),
#  (b'CII from a double DLA', 1),
#  (b'[K] missing CIV next door b/c of conti?', 1),
#  (b'real abs is to the right', 1),
#  (b'shifted abs to left', 1),
#  (b'shifted to right', 1),
#  (b'[K] ghost emission; [J] contin too high', 1),
#  (b'[K] bad conti for SiII', 1),
#  (b'sightline is messed', 1),
#  (b'[K] SiII; check (was RTG=3)', 1),
#  (b'[K] component to red?', 1),
#  (b'[J] contin high bad conti', 1),
#  (b'[K] sky lines; check (was RTG=3); KLC was 2; RAS 1; no HI; KLC now 1', 1),
#  (b'KLC was 0; JMO 2; real system to red; KLC still 0', 1),
#  (b'MgII!', 1),
#  (b'[K] ghost emission; bad conti; [J] real abs is to the right', 1),
#  (b'[K] ghost emission; KLC was 0; RAS 2; stuff around real; KLC still 0', 1),
#  (b'abs is to the left', 1),
#  (b'abs shifts to right', 1),
#  (b'same as one I shifted to the left', 1),
#  (b'big CIV missed to the right', 1),
#  (b'[J] real abs to the right conti fail', 1),
#  (b'real to the right, no HI, no alternatives?', 1),
#  (b'KLC orig 1; RAS 2; intrinsic; CII to red; KLC now 2', 1),
#  (b'[K] broad line to blue is candidate (real!)', 1),
#  (b'Weird, this is CII/CII* from a DLA', 1),
#  (b'KLC orig 0; JMO 2; referring to system to blue probably; KLC still 0', 1),
#  (b'big CIV blend; KLC was 0; JMO 2; blend with real system; KLC now 2', 1),
#  (b'contin high.  blend?; KLC orig 0; JMO 2; fold into system to red; KLC now 1',
#   1),
#  (b'contin high.  blend?', 1),
#  (b'ghost emission', 1),
#  (b'conti riding a bit high because of real one to the left', 1),
#  (b"big one that's real to the right.  This is SiIV!", 1),
#  (b'contin dipping too low', 1),
#  (b'KLC orig 0; JMO 2; real system to red; nothing else obvious to call it; KLC now 2',
#   1),
#  (b'[K] bad conti; incl. red comp.?', 1),
#  (b'[K] bad conti; [J] contin a bit high', 1),
#  (b'[K] ghost emission; ghost emission; sky lines', 1),
#  (b'I think the other 2 are real', 1),
#  (b'cont a little high but probably OK', 1),
#  (b'KLC orig 0; JMO 2; leave it to be the system to red only; KLC still 0', 1),
#  (b'[K] NV!', 1),
#  (b'part of BAL?', 1),
#  (b'[J] contin too high', 1),
#  (b'KLC orig 0; JMO 2; same system as next; KLC now 2', 1),
#  (b'[K] AlIII blend', 1),
#  (b'contin too low', 1),
#  (b"[K] check; shouldn't accept like others?", 1),
#  (b'[K] SiIV, yes, SiIV', 1),
#  (b'[K] FeII, AlIII', 1),
#  (b'[J] moved to left', 1),
#  (b'[K] CII twice;  check (was RTG=1)', 1),
#  (b'[K] CII; CIV; check (was RTG=3); KLC was 0; RAS 2; calling it CII to blue and CIV to red; KLC now 2',
#   1),
#  (b'KLC was 3 but voted down by both Rob and John!!! Overruled!', 1),
#  (b'[K] SiIV? (see Lya forest); check (was RTG=3); KLC orig 0; RAS 2; same as next sytem; KLC now 2',
#   1),
#  (b'[K] ghost emission; but intrinsic CIV is real; how to handle?; check (was RTG=3); overrule Rob; KLC now 0',
#   1),
#  (b'[K] check (was RTG=3); KLC was 0; RAS 3; real systems surround; KLC now 0',
#   1),
#  (b'KLC orig 0; JMO 2; but SiIV 1402 actually blend on blue; KLC still 0', 1),
#  (b'contin high in 1548', 1),
#  (b'KLC was 0; JMO 2; is same as next yes system; KLC now 2', 1),
#  (b'[K] ghost emission, bad conti + a stray line', 1),
#  (b'[K] SiIV; check (was RTG=3)', 1),
#  (b'[J] abs shifted to the right', 1),
#  (b'same as previous', 1),
#  (b'contin high; KLC orig 0; JMO 2; same as real system to red; KLC now 2', 1),
#  (b'[K] Bad conti', 1),
#  (b'contn high', 1),
#  (b'[K] SiII; SiIV; check (was RTG=3)', 1),
#  (b'[K] MgI; FeII', 1),
#  (b'abs shifted', 1),
#  (b'KLC was 0; JMO 2; real system to red but this 1548 is SiII; KLC still 0',
#   1),
#  (b'[K] CII; check', 1),
#  (b'[K] AlII; broad line to red that should be candidate; check (was RTG=3); KLC orig 1; RAS 2; KLC now 2',
#   1),
#  (b'[K] broad line to blue that should be candidate', 1),
#  (b'contin high in 1550', 1),
#  (b'[K] FeII; MgI', 1),
#  (b'[K] SiIV; check (was RTG=3); KLC orig 2; RAS 1; likely is SiIV; KLC now 1',
#   1),
#  (b'real CIV, but a pair of them', 1),
#  (b'[K] Shameful to accept b/c other lines', 1),
#  (b'[K] CII towards blue; check', 1),
#  (b'[K] FeII is candidate 1550', 1),
#  (b'KCL was 1; RAS 2; BAL; KLC now 2', 1),
#  (b'KLC orig 0; JMO 2; red wing plausibly SiII but need something to make 1550 of previous so strong; KLC now 2',
#   1),
#  (b'[J] HUGE AlII (make sure it gets the CIV, z=2.047', 1),
#  (b'this is associated abs; KLC orig 0; JMO 2; bad conti and intrinsic; KLC still 0',
#   1),
#  (b'this is associated abs', 1),
#  (b'Left is FeII 2382', 1),
#  (b'[K] CIV in middle is real but severely bad pixel messes this up so allowed to include?',
#   1),
#  (b'bad sky on 1548, but abs real from other ions', 1),
#  (b'[K] SiII 1808', 1),
#  (b'bad sky on 1550, but abs real', 1),
#  (b'[K] MgII forest?', 1),
#  (b'[K] FeII 1808 in 1548?; SiII in 1550; check (was RTG=3); KLC orig 2; RAS 1; FeII and SiII; KLC now 0',
#   1),
#  (b'sky lines; CIV; KLC orig 0; JMO 2; system to red is real; KLC now 2', 1),
#  (b'[K] Also shameful to accept', 1),
#  (b'KLC orig 0; JMO 2; thsi sightline will be pitched; KLC now 2', 1),
#  (b'[K] ghost emission later right is MgII...', 1),
#  (b'[K] MgI?', 1),
#  (b'[J] contin bad conti', 1),
#  (b'bad sky effects 1550, but it looks real', 1),
#  (b'Where are your notes, omeara?', 1),
#  (b'[K] incl. comp. to red?', 1),
#  (b'KLC orig 1; RAS 2; since no other thing to call it; KLC now 2', 1),
#  (b'MgII is there', 1),
#  (b'KLC orig 0; JMO 3; real system is duplicated; KLC now 3', 1),
#  (b'[J] bad sky?', 1),
#  (b'part of it is cII', 1),
#  (b'[K] SiII 1808 blended 1548?', 1),
#  (b'[J] real abs to either side...yes', 1),
#  (b'[J] same as previous', 1),
#  (b'[K] AlIII blend 1550', 1),
#  (b'[K] broad line to blue should be candidate (real!)', 1),
#  (b'[K] SiIV 1402 in 1550 but SiIV 1393 has SiII 1526; bad conti', 1),
#  (b'[K] ghost emission; [J] contintoo high, but good HI Not buying the conti, sorry J.',
#   1),
#  (b'[K] definitely multi-comp', 1),
#  (b'KLC orig 0; JMO 2; leave it to be system to red; KLC now 1', 1),
#  (b'KLC orig 1; RAS 2; for nothing else to call it say KLC now 2', 1),
#  (b'[K] DLA Zn?; [J] shifting to righr', 1),
#  (b'blend in  big abs', 1),
#  (b'SiIV from known CIV', 1),
#  (b"[K] check; shouldn't accept?", 1),
#  (b'[J] other ions', 1),
#  (b"[K] ghost emission; check (was RTG=0); KLC was 3; RAS 1; CIV to red can't be blended so KLC now 1",
#   1),
#  (b'no, this is OII+SiII', 1),
#  (b'KLC was 0; JMO 2; likely part of system to red; KLC now 2', 1),
#  (b'CII/CII* from DLA', 1),
#  (b'[K] FeII 1808 but has strong HI; check', 1),
#  (b'[J] see FeII, MgII', 1),
#  (b'KLC was 0; JMO 2; part of real system to red; KLC now 2', 1),
#  (b'[K] check (was RTG=3); KLC was 0; RAS 2; is real system to red but not this; KLC 0',
#   1),
#  (b'[K] check (was RTG=3); KLC was 1; RAS 2; real system to red (or SiIV?!); KLC now 2',
#   1),
#  (b'[K] SiIV; check (was RTG=2); No, I think this is CIV', 1),
#  (b'[J] CII', 1),
#  (b'[K] MgI?; ghost emission; check (was RTG=3)', 1),
#  (b'KLC was 0; JMO 2; include in real system to red; KLC now 2', 1),
#  (b'[K] many broad lines should be candidates', 1),
#  (b'KLC was 0; JMO 2; include with system to red; KLC now 2', 1),
#  (b'[K] SiII 1526; [J] CII', 1),
#  (b'[K] some FeII 1608 blend in 1548', 1),
#  (b'[K] broad line should be 3 candidates (real!)', 1),
#  (b'contin failure on blue side', 1),
#  (b'[K] not AlII, CII', 1),
#  (b'[J] has HI', 1),
#  (b'[K] bounds?; check', 1),
#  (b'MgII; KLC was 2; RAS 0; let it be MgII; KLC now 0', 1),
#  (b'[K] other CIV real; ghost emission', 1),
#  (b'KLC was 3; JMO 1; no problem with it; KLC now 2', 1),
#  (b'[J] mgII complex', 1),
#  (b'[K] bad conti; AlIII blend 1550?', 1),
#  (b'[K] broad blue wing should be candidate', 1),
#  (b'[J] has big HI...also has poorly subtracted sky lines', 1),
#  (b'KLC orig 2; RAS 1; nothing else to call it; KLC still 2', 1),
#  (b'1550 is SiIV', 1),
#  (b'KLC orig 0; JMO 2; let other two systems stand for this one; KLC now 1',
#   1),
#  (b'KLC orig 2; RAS 1; but there are other absorption lines; KLC still 2', 1),
#  (b'[J] CII Actualy SiII', 1),
#  (b'[J] bad skysub?', 1),
#  (b'skysub?', 1),
#  (b'[K] ghost emission?; [J] contin.  shifted to right', 1),
#  (b'[K] AII', 1),
#  (b'[K] SiII in both lines?; check', 1),
#  (b'[K] SiII some', 1),
#  (b'[J] 2 MgIIs, contin dipping too low', 1),
#  (b'contin low', 1),
#  (b'skysub', 1),
#  (b'[K] SiIV and CIV', 1),
#  (b'[K] SiIV blend little to blue', 1),
#  (b'KLC orig 0; JMO 2; intrinsic; KLC now 2', 1),
#  (b'[K] AlII, SiIV', 1),
#  (b'has HI; KLC orig 0; JMO 2; redshift shifted too blue but is real; KLC 2 now',
#   1),
#  (b'[J] SiIV of a BAL', 1),
#  (b'BAL; KLC orig 3; JMO 0; but are keeping BALs; KLC still 3', 1),
#  (b'[K] bad conti; broad line should be another candidate', 1),
#  (b'in EML of CIV?  contin', 1),
#  (b'associated abs', 1),
#  (b'ok HI', 1),
#  (b'possible CIV?', 1),
#  (b'[K] CIV, SiIV', 1),
#  (b'[J] huge HI', 1),
#  (b'1548 is 1526', 1),
#  (b'[J] 2 abs, one to left, one to right', 1),
#  (b'[J] looks like some MgII as well', 1),
#  (b'[J] 1550 is 1526', 1),
#  (b'[K] FeII 1608 blend w/ 1550', 1),
#  (b'KLC orig 0; JMO 2; let the real system to red stand for this one; KLC now 1',
#   1),
#  (b'[J] sky effecting 1548?', 1),
#  (b'1548 is 1608', 1),
#  (b'kLC orig 0; JMO 2; let real system to red count for this; KLC now 1', 1),
#  (b'contin nearby is too low', 1),
#  (b'sky effecting 1550?', 1),
#  (b'conti; KLC was 2; RAS 1; but has HI; KLC still 2', 1),
#  (b'[J] possible mgii', 1),
#  (b'KLC was 0; JMO 2; let real system to red stand for this; KLC now 1', 1),
#  (b'[J] big HI.  Sky line effecting CIV', 1),
#  (b'KLC was 0; JMO 2; actually MgII; KLC still 0', 1),
#  (b'BAL?; KLC was 0; JMO 2; count as intrinsic; KLC now 2', 1),
#  (b'see previous', 1),
#  (b'[K] MgII w/ no FeII? / CIV BAL', 1),
#  (b'huge HI', 1),
#  (b'[K] SiIV blend 1548', 1),
#  (b'[K] MgII complex?', 1),
#  (b'[K] MgII complex; bad conti', 1),
#  (b'[K] MgII complex?; bad conti', 1),
#  (b'blend on 1550?', 1),
#  (b'[K] SiII 1526 and SiIV', 1),
#  (b'BAL?; KLC was 0; JMO 2; really intrinsic; KLC now 2', 1),
#  (b'see prev; KLC was 0; JMO 2; really intrinsic; KLC now 2', 1),
#  (b'[J] SiIV BAL', 1),
#  (b'[K] check; sky lines (was RTG=0)', 1),
#  (b'[J] bad sky? bad conti', 1),
#  (b'FeII?', 1),
#  (b'Conti a little weird', 1),
#  (b'KLC was 0; JMO 2; let the real ssytem to red count for it; KLC still 0',
#   1),
#  (b'KLC was 0; JMO 2; let real system to blue count for this; KLC now 0', 1),
#  (b'[K] check; rest is real (was RTG=0); KLC 0; RAS 2; let real system to blue count for this; KLC 0 now',
#   1),
#  (b'[K] check; rest is real (was RTG=0)', 1),
#  (b'[K] FeII 2600 blend in 1550?', 1),
#  (b'1550=1548?  sky?', 1),
#  (b'contin; KLC was 0; JMO 2; let real system to red stand for this; KLC 0',
#   1),
#  (b'[K] braod, should be three candidates; bounds?', 1),
#  (b'DLA; KLC 0; JMO 3; let real system to blue stand for this; KLC 0', 1),
#  (b'contin too low?  missing 1550 of nearby CIV?', 1),
#  (b'KLC orig 1; RAS 2; nothing else to call it; KLC 2 now', 1),
#  (b'[K] check (was RTG=0); KLC orig 2; RAS 1; but has other lines; KLC 2 still',
#   1),
#  (b'KLC was 0; JMO 2; same as the real system next; KLC now 2', 1),
#  (b'[J] BAL?', 1),
#  (b'[K] CII is 1548; check (was RTG=3); KLC was 1; RAS 2; seems like CII; KLC still 1',
#   1),
#  (b'[K] SiIV; DLA PbII?', 1),
#  (b'[J] zqso wrong?', 1),
#  (b'KLC was 1; RAS 2; let this be like the prev one so KLC 2 now', 1),
#  (b'[K] bad conti; FeII blend 1548 but not account all; check', 1),
#  (b'BAL?; KLC was 0; JMO 2; really is intrinsic; KLC now 2', 1),
#  (b'[J] big MgII', 1),
#  (b'[K] FeII 1608 blend 1548; is FeII 1611 likely?; check (was RTG=3)', 1),
#  (b'KLC was 0; JMO 2; let be consistent with next; KLC now 2', 1),
#  (b'blend w/ 1526', 1),
#  (b'[J] Contin, SiII.  DLA EML at lower z?', 1),
#  (b'[K] how is this detected?', 1),
#  (b'KLC was 0; JMO 2; let neighbor represent this one; KLC now 1', 1),
#  (b'[K] FeII; bad conti', 1),
#  (b'[J] SiIV?', 1),
#  (b'[J] blend', 1),
#  (b'KLC was 2; RAS 1; but by rule of nothing else to call it; KLC still 2', 1),
#  (b'KLC was 2; RAS 1; but actually has other lines and HI; KLC still 2', 1),
#  (b'contin; KLC was 0; JMO 2; let the other stand for this; KLC now 1', 1),
#  (b'Not a QSO!', 1),
#  (b'[K] SiIV 1393 in 1550', 1),
#  (b'[K] FeII 1608 is little guy to red', 1),
#  (b'[K] MgII instead of 1550?; check (was RTG=3); KLC was 1; RAS 2; but really CIV and MgII; KLC 1 now',
#   1),
#  (b'[K] SiIV; other CIV', 1),
#  (b'[J] 1334', 1),
#  (b'[K] check (was RTG=0) no HI', 1),
#  (b'[J] SiIV not SiIV?', 1),
#  (b"[K] this isn't fair?", 1),
#  (b'KLC was 3; JMO 1; but has other absorption lines; KLC still 2', 1),
#  (b'[K] check (was RTG=0) MgII', 1),
#  (b'KLC was 0; JMO 3; let other absorber stand for it; KLC 1 now', 1),
#  (b'KLC was 0; JMO 2; let it match its acccepted duplicate; KLC now 2', 1),
#  (b'KLC was 0; JMO 2; neighbor is real; this is bad conti; KLC still 0', 1),
#  (b'[J] DLA', 1),
#  (b'KLC was 0; JMO 2; let match duplicate; KLC 2', 1),
#  (b'KLC was 2; RAS 1; but has other lines; KLC still 2', 1),
#  (b'[J] zem wrong?', 1),
#  (b'KLC was 0; JMO 2; intrinsic; let match duplicate; KLC now 2', 1),
#  (b'contin; KLC was 1; RAS 2; let match duplicate; KLC now 2', 1),
#  (b'[K] SiIV blend 1550', 1),
#  (b'[K] check; probability of string?', 1),
#  (b'[K] SiII 1526; [J] SiII', 1),
#  (b'contom by SiIV', 1),
#  (b'2 systems?', 1),
#  (b'[K] SiIV? Yes!', 1),
#  (b'[K] SiII blend in 1548', 1),
#  (b'KLC was 1; RAS 2; for nothing else to call it; KLC now 2', 1),
#  (b'intrinsic?', 1),
#  (b'contam by SiIV', 1),
#  (b'[K] DLA CoII?', 1),
#  (b'KLC was 2; RAS 1; match duplicate; KLC now 1 (seems inconsistent with the just accept it)',
#   1),
#  (b'[J] contin No HI', 1),
#  (b'[J] abs from DLA', 1),
#  (b'KLC was 0; JMO 2; let neighbor represent this; KLC now 1', 1),
#  (b'KLC was 2; RAS 0; but really intrinsic and should count (though BAL); KLC still 2',
#   1),
#  (b'KLC was 0; JMO 3; let match duplicate; KLC now 3', 1),
#  (b'real abs to the right', 1),
#  (b'[K] check; FeII? (was RTG=0)', 1),
#  (b'[K] SiII 1526 too at least; bad conti', 1),
#  (b'[K] SiII in 1548?; check', 1),
#  (b"[K] check (was RTG=0); KLC was 1; RAS 2; but really can't have real CIV to blue blended; KLC now 1",
#   1),
#  (b'KLC was 2; RAS 1; tough call but real system is in search bounds; KLC 2 still',
#   1),
#  (b'[K] bad conti; [J] BAL contin', 1),
#  (b'[K] bad conti; [J] see prev', 1),
#  (b'sky effecting 1548?  ral abs', 1),
#  (b'[J] FeII Not FeII', 1),
#  (b'real abs to left (but where is 1550?  is there a giant offset between low and high ions?)',
#   1),
#  (b'KLC was 0; JMO 3; let real neighboring system represent; KLC now 1', 1),
#  (b'[K] broad line to blue should be two', 1),
#  (b'[J] 1526', 1),
#  (b'[J] looks bad, but HI implies yes', 1),
#  (b'[K] bad conti?', 1),
#  (b'[K] component to blue is real; broad line should be two?', 1),
#  (b'[K] SiII 1526 some; bad conti', 1),
#  (b'2x mgII', 1),
#  (b'[K] CII blend/is 1550; SiIV 1402 blend 1548; check (was RTG=3); KLC was 2; RAS 1; has HI and blending not severe; KLC 2 still',
#   1),
#  (b'bih HI', 1),
#  (b'KLC was 0; JMO 2; let neighbor represent; KLC 1 now', 1),
#  (b'same abs as previous?  double count?', 1),
#  (b"KLC was 2; RAS 1; guess it's risky so KLC now 1", 1),
#  (b'[J] real abs to right', 1),
#  (b'[J] giant BAL qso', 1),
#  (b'Mg II on giant BAL qso', 1),
#  (b'[J] giant BAL', 1),
#  (b'[K] SiII 1526; [J] blended wi SiII', 1),
#  (b'KLC was 2; RAS 1; but intrinsic and real; KLC still 2', 1),
#  (b'bal complex?', 1),
#  (b'KLC was 0; JMO 2; let match duplicates; KLC now 2', 1),
#  (b'[K] MgII and SiIV', 1),
#  (b'[K] another CIV to red', 1),
#  (b'[K] SiIV 1393/is blend 1548; check (was RTG=3); KLC was 0; RAS 2;  blends are real; KLC 0 still',
#   1),
#  (b'[K] SIIV round it', 1),
#  (b'[K] AlIII blended with 1548', 1),
#  (b'[J] contin problem in CIV EML', 1),
#  (b'[J] crazy number of big systems', 1),
#  (b'[K] SiII to blue', 1),
#  (b'bal outflow?; KLC was 0; JMO 2; let neighbor represent; KLC now 1', 1),
#  (b'[K] AlIII blend 1548?', 1),
#  (b'[K] sky lines; check (was RTG=0)', 1),
#  (b'[K] check (was RTG=0); KLC was 1; RAS 2; let KLC now be 2', 1),
#  (b'KLC was 2; JMO 1; yes they are seperate; KLC now 1', 1),
#  (b'[K] OI, SiII at +4000 km/s from QSO', 1),
#  (b'[K] another CIV too', 1),
#  (b'contin; kLC was 0; JMO 2; let neighbor represent; KLC now 1', 1),
#  (b'[K] check (was RTG=3); KLC was 0; RAS 2; one of these complcated triplets; let them not be blended; KLC now 1',
#   1),
#  (b'KLC was 3; JMO 1; clearly is; KLC stays 3', 1),
#  (b'[K] ghost emission; SiII blend 1550', 1),
#  (b'mini BAL', 1),
#  (b'conitn', 1),
#  (b'[K] broad line to blue should be 2 candidates (real)', 1),
#  (b'HI!', 1),
#  (b'[K] SiIV twice?; check', 1),
#  (b'[K] FeII 1808 but no other; check', 1),
#  (b'blend w/ MgII', 1),
#  (b'[K] SiIV twice; check (was RTG=3)', 1),
#  (b'[K] DLA SiIV?', 1),
#  (b'[K] DLA SiIV?; [J] contin', 1),
#  (b'[J] contin  [note contin misses abs far to right]', 1),
#  (b'[J] definite abs to left', 1),
#  (b'KLC was 0; JMO 2; let neighbor represent (bad conti too); KLC now 1', 1),
#  (b'[K] SiIV 1393 blend 1548 and another, 1550', 1),
#  (b'[K] check; other CIV blending', 1),
#  (b'[K] What to do with these?', 1),
#  (b'[K] check; likely just two CIV (was RTG=3); KLC was 0; RAS 2; keep as seperate; KLC now 1',
#   1),
#  (b'BAL?; KLC was 0; JMO 2; intrinsic real; KLC now 2', 1),
#  (b'[J] effected by sky,but real', 1),
#  (b'[K] CII is 1548; AlIII is 1550', 1),
#  (b'KLC was 2; RAS 1; clearly intrinsic but we keep; KLC still 2', 1),
#  (b'[K] DLA SiII 1808', 1),
#  (b'[K] SiIV forest', 1),
#  (b'KLC was 2; RAS 1; clearly intrinsic and keep; KLC still 2', 1),
#  (b'big CIV missed by contin to right', 1),
#  (b'[K] SiIV 1402 blend both', 1),
#  (b'[K] should have more candidtes', 1),
#  (b'[J] real abs to either side', 1),
#  (b'big MgII?', 1),
#  (b'[K] bad conti; FeII maybe blend 1548', 1),
#  (b'[K] FeII blend 1550; FeII blend 1548', 1),
#  (b'[K] check (was RTG=3) also MgII', 1),
#  (b'[J] effected by sky but good HI SiIV too', 1),
#  (b'[K] should line to blue be candidate (real)?', 1),
#  (b'[K] Check (was RTG=3); KLC was 0; RAS 2; no blending necessarly; KLC now 1',
#   1),
#  (b'QSO?', 1),
#  (b'[K] AlII blend 1548?', 1),
#  (b'[K] check; ghost emission (was RTG=3)', 1),
#  (b'CII prox DLA', 1),
#  (b'[K] SiIV; but other part is real; check what to do (was RTG=3); KLC ws 0; RAS 3; and real system to red but not picked up in survey; KLC now 1',
#   1),
#  (b'[K] check; likely just CIV to red (was RTG=3)', 1),
#  (b'[K] ghost emission; check, likely just CIV around (was RTG=3); KLC was 0; RAS 3; but no blending; KLC now 1',
#   1),
#  (b'[K] ghost emission; check (was RTG=3); KLC was 0; RAS 2; but bad conti and real CIV to red; KLC now 1',
#   1),
#  (b'[K] AlII of DLA', 1),
#  (b'[K] SiIV? and FeII', 1),
#  (b'[K] CII twice blend both', 1),
#  (b'[K] SiIV; MgII', 1),
#  (b'chunky MgII?  COntin', 1),
#  (b'[K] ghost emission; convinced by other ions?; [J] contin', 1),
#  (b'AAS complex', 1),
#  (b'2 components?', 1),
#  (b'KLC was 0; JMO 2; intrinsic and match duplicates; KLC now 2', 1),
#  (b'[J] MgII2800', 1),
#  (b'[K] SiII 1808 blend to red', 1),
#  (b'[K] AlII?; [J] MgII contam on 1548', 1),
#  (b'good MgII', 1),
#  (b'[J] outskirts of DLA', 1),
#  (b'Huge AlII 1670', 1),
#  (b'big blend of AAS CIV', 1),
#  (b"not sure what the heck this is, but CIV works.  it's HUGE though, and the QSO  has a lot of HIGE abs",
#   1),
#  (b'[K] FeII 1608', 1),
#  (b'[J] mgII cluster?', 1),
#  (b'mgII cluster?; KLC was 3; JMO 1; has HI; KLC now 2', 1),
#  (b'[K] CIV to blue', 1),
#  (b'[J] real abs to left, possible blend?', 1),
#  (b'KLC was 2; RAS 1; call it spurious; KLC now 1', 1),
#  (b'big blend', 1),
#  (b'big blend; KLC was 0; JMO 2; let neighbor represent; KLC now 1', 1),
#  (b'contin.  sky?', 1),
#  (b'[J] contin1', 1),
#  (b'[K] ghost emission; check (was RTG=3)', 1),
#  (b'MgII confirmed', 1),
#  (b'[K] broad line to red should be candidate?', 1),
#  (b'Amazing, MgII conf', 1),
#  (b'gnarly HI; KLC was 0; JMO 2; let neighbore represent; KLC now 1', 1),
#  (b'gnarly HI', 1),
#  (b'z for this qso completely wrong, flagging as BA to stick out', 1),
#  (b'[J] see prev, z fail - in the forest!', 1),
#  (b"In the forest!; KLC had 2; RAS 0; and it's true that zem = 2.78295 so all wrong; KLC now 0",
#   1),
#  (b'forest; KLC was 1; RAS 0; true in forest; KLC now 0', 1),
#  (b'see prev; KLC was 1; JMO 0; true in forest; KLC now 0', 1),
#  (b'[J] see prev in the forest!', 1),
#  (b'[K] check (was RTG=3); KLC was 0; RAS 3; but neighbores are real; KLC now 1',
#   1),
#  (b'sky?', 1),
#  (b'[K] all CIV?', 1),
#  (b'[K] check (was RTG=3); KLC was 3; RAS 1; but has HI and though intrinsic; KLC now 2',
#   1),
#  (b"KLC was 1; RAS 2; he's too optimistic; KLC still 1", 1),
#  (b'[K] add red component?', 1),
#  (b'[K] add to blue doublet?', 1),
#  (b'[K] bad conti; check (was RTG=3); KLC was 0; RAS 3; bad conti and real neighbor; KLC now 1',
#   1),
#  (b'[K] check (was RTG=3); KLC was 0; RAS 3; but no need to blend; KLC now 1',
#   1),
#  (b'[K] cbeck', 1),
#  (b'[K] SiIV 1393 is 1548', 1),
#  (b'[K] SiIV 1402 is 1550; FeII', 1),
#  (b'[K] need to incl. blue comp.', 1),
#  (b'KLC was 1; RAS 2; other lines; KLC now 2', 1),
#  (b'[K] CIV to red?', 1),
#  (b'[J] FeII Not FeII! DLA!', 1),
#  (b'[K] ghost emission; FeII is 1550; SiIV is 1548; check (was RTG=3)', 1),
#  (b'[J] SiII?', 1),
#  (b'KLC had 1; RAS 2; 1550 likely SiII blend; blend CIV; KLC now 2', 1),
#  (b'[K] CaII?; check (was RTG=3)', 1),
#  (b'ghost emission conti', 1),
#  (b'2 MgIIs', 1),
#  (b'[K] AlII; check (was RTG=3)', 1),
#  (b'[J] same as previous?   saying 0 so as not to double count', 1),
#  (b'OI from fatty DLA; KLC was 2; RAS 0; true is DLA line; KLC now 0', 1),
#  (b'CII from DLA fatty', 1),
#  (b'[J] big SiIV', 1),
#  (b'blend?  good MgII', 1),
#  (b'blend?  good MgII; KLC was 0; JMO 2; let neighbor represent; KLC now 1',
#   1),
#  (b'contin nearby misses abs', 1),
#  (b'KLC was 1; RAS 2; but SiIV lines; KLC now 0', 1),
#  (b'[K] SiIV blend both; check (was RTG=3)', 1),
#  (b'KLc was 0; JMO 2; let neighbor represent; KLC now 1', 1),
#  (b'[J] blend? Contin', 1),
#  (b'[J] skyline contam, but likely real', 1),
#  (b'contin. BAL', 1),
#  (b'[J] contin.  huge BAL', 1),
#  (b'[K] MgII complex', 1),
#  (b'a little to the right', 1),
#  (b'contam By fe2 1608', 1),
#  (b'[J] contin misses abs in eml', 1),
#  (b'[K] bad conti; [J] continum failure in CIV eml', 1),
#  (b'[J] sky issues', 1),
#  (b'[K] MgII?! Contin', 1),
#  (b'BAL.  contin; KLC was 0; JMO 2; let neighbor represent; KLC now 1', 1),
#  (b'BAL.  contin', 1),
#  (b'[K] ghost emission; [J] contin, but HI', 1),
#  (b'[K] SiIV of crazy intrinsic CIV; check (was RTG=3)', 1),
#  (b'MgII?; KLC was 0; JMO 2; let neighbor represent; KLC now 1', 1),
#  (b'[J] MgII?', 1),
#  (b'contin failure misses ALS', 1),
#  (b"[K] bad conti; check shouldn't intrinsic be guaranteed?", 1),
#  (b'[K] FeII blend 1550; check (was RTG=3); KLC was 2; RAS 1; is indeed blended but other lines means real; KLC still 2',
#   1),
#  (b'sky contam?', 1),
#  (b'contin misses BAL', 1),
#  (b'[J] is this a QSO?  rating BAL to point it out.', 1),
#  (b'[K] SiIV 1393 blend 1550; AlII blend 1548', 1),
#  (b'[K] FeII, SiII 1526', 1),
#  (b'[K] SiIV around', 1),
#  (b'[K] check (was RTG=0); KLC was 1; RAS 2; other lines; KLC now 2', 1),
#  (b'Al', 1),
#  (b'CII from DLA', 1),
#  (b'[J] blend w/ prev', 1),
#  (b'[K] broad blue component should be component', 1),
#  (b'[K] SiIV 1393 blend/is 1550; check (was RTG=3)', 1),
#  (b'[K] CII blend 1550', 1),
#  (b'[K] FeII blend 1550', 1),
#  (b'[K] AlIII; check (was RTG=3)', 1),
#  (b'KLC was 0; JMO 3; let neighbor represent; KLC 1 now', 1),
#  (b'[K] sky lines; bad conti', 1),
#  (b"MgII; KLC was 3; RAS 0; though I think it's real, reflect duplicate; KLC now 1",
#   1),
#  (b'[K] surrounded by SiIV', 1),
#  (b'[K] AlII blend 1548; check', 1),
#  (b'HI.  Sky issues', 1),
#  (b'sky issues; KLC was 0; JMO 2; let neighbor represent; KLC now 1', 1),
#  (b'better fit by mgii', 1),
#  (b'[K] FeII; DLA OI?', 1),
#  (b'blend; KLC was 0; JMO 2; let neightbor represent; KLC now 1', 1),
#  (b"SiIV; KLC was 2; RAS 0; it's SiIV twice; KLC now 0", 1),
#  (b'AlII1670; KLc was 2; RAS 0; not AlIII 1670 b/c relies on CIV of other system; intrinsic but KLC still 2',
#   1),
#  (b'[K] check; might just be redward CIV (was RTG=3); KLC was 1; RAS 3; real system to left; probably need blending; KLC now 2',
#   1),
#  (b'[J] 1550 blend?', 1),
#  (b'1550 blend?', 1),
#  (b'blend w mgii?', 1),
#  (b'KLC was 1; RAS 2; without any other ID; KLC now 2', 1),
#  (b'[J] sky, but real', 1),
#  (b'huge abs', 1),
#  (b'[J] 1550 blend', 1),
#  (b'[K] not CII, FeII, AlII', 1),
#  (b'[K] SiIIV surrounds, CII is candidate 1548; [J] 1548 blend', 1),
#  (b'[K] SiII 1526 (which means CIV has another component)', 1),
#  (b'[K] SiIV; FeII', 1),
#  (b'KLC was 0; JMO 2; Let neighbor represent; KLC now 1', 1),
#  (b'big blended abs', 1),
#  (b'[K] check; bounds?', 1),
#  (b'[K] AlII blend 1548?; check', 1),
#  (b'[K] CII; SiIV', 1),
#  (b'[J] complex?', 1),
#  (b'[J] abs to the left is missed by line finder', 1),
#  (b'sky, but real (see SiIV', 1),
#  (b'KLC was 1; RAS 2; nothing else to ID it; KLC now 2', 1),
#  (b'[K] ghost emission; other CIV', 1),
#  (b'[K] ghost emission; SiII blend/is 1550; check', 1),
#  (b'AlIII + conti', 1),
#  (b'huge MgII', 1),
#  (b'[K] MgII blend both; other line?; check (was RTG=3); KLC was 0; RAS 3; true; KLC now 3',
#   1),
#  (b'some contam by SiIV in 1550', 1),
#  (b'CII?', 1),
#  (b'[K] CII is 1550; FeII 1608 is 1548', 1),
#  (b'[K] SiIV blend 1550; check', 1),
#  (b'so close to a real one!', 1),
#  (b'mgii?', 1),
#  (b'1550 blended?', 1),
#  (b'contin.  sky.', 1),
#  (b'[K] SiII 1526? or SiIV and FeII', 1),
#  (b'[K] What is this?; FeII', 1),
#  (b'KLC was 2; RAS 1; now KLC 1', 1),
#  (b'[J] doubtful', 1),
#  (b'KLC was 0; JMO 2; probably need blend in prev. 1550 line so KLC now 2', 1),
#  (b'[J] mgii', 1),
#  (b'conin; KLC was 0; JMO 2; let neighbor represent; KLC now 1', 1),
#  (b'conin', 1),
#  (b'[J] bal?  contin nearby misses abs', 1),
#  (b'KLC was 1; RAS 2; has other lines; KLC now 2', 1),
#  (b'contin.  blend?', 1),
#  (b'contin missis abs in CIV EML', 1),
#  (b'BAL?; KLC was 0; JMO 2; let neighbor represent; KLC now 1', 1),
#  (b'[K] SiIV both', 1),
#  (b'[K] SiIV 1526', 1),
#  (b'BAL nearby', 1),
#  (b'[J] outflow?', 1),
#  (b'abs missed in CIV eml', 1),
#  (b'[J] SiIV, also contin issues in EML', 1),
#  (b'[J] contin.  AAS?', 1),
#  (b'big MgII', 1),
#  (b'[K] Based on other ions?', 1),
#  (b'[K] SiII of MgII', 1),
#  (b'[K] CII twice?; check (was RTG=3)', 1),
#  (b'real abs to right?', 1),
#  (b'[J] FeII, huh?', 1),
#  (b'[J] AAS?', 1),
#  (b'see prev; KLC now 0; JMO 2; let neighbor represent; KLC now 1', 1),
#  (b'[K] AlII twice', 1),
#  (b'KLC was 1; RAS 2; has HI; KLC now 2', 1),
#  (b'contin.  stronger abs to right', 1),
#  (b'[J] contin?  has HI', 1),
#  (b'[K] SiII; sky lines', 1),
#  (b'[K] DLA PbI?', 1),
#  (b'hI', 1),
#  (b'contin; KLC was 0; JMO 2; match duplicate; KLC now 2', 1),
#  (b'KLC was 1; RAS 1; nothing else to call it; KLC now 2', 1),
#  (b'[K] what is this?', 1),
#  (b'contin misses abs n EML to right.  blend?', 1),
#  (b'1548 is MgII 2800', 1),
#  (b'bal complex, some missed by contin', 1),
#  (b'[K] SiII 1526 on blue', 1),
#  (b'[J] real abs missed by contin to right.  have shifted abs to get it', 1),
#  (b'blend w/ SiIV; KLC was 0; JMO 2; match duplicate; KLC now 2', 1),
#  (b'CIV complex', 1),
#  (b'[K] MgII blend/is 1548; SiII', 1),
#  (b'[J] shifted to left. contin', 1),
#  (b'CaII in 0.6 MgII system!', 1),
#  (b'AAS complex?; KLC 0; JMO 2; match duplicate; KLC now 2', 1),
#  (b'[J] accounted for before', 1),
#  (b'contin misses big CIV outflow at EML', 1),
#  (b'FeII1608', 1),
#  (b'[J] better HI for abs to right', 1),
#  (b'KLC was 1; RAS 2; match duplicate; KLC now 2', 1),
#  (b'[K] SiII 1808?', 1),
#  (b'[J] 1550 is MgII 2796', 1),
#  (b"[K] check (was RTG=0); KLC was 1; RAS 2; he's right; KLC now 2", 1),
#  (b'[K] SiIV 1393 blend 1550', 1),
#  (b'[J] 1550 blend?  good HI', 1),
#  (b'[K] DLA FeII*?', 1),
#  (b'possible CaII in other system', 1),
#  (b'contin misses abs elsewhere, good HI here', 1),
#  (b'outflow?; KLC was 0; JMO 2; let neighbor represent; KLC now 1', 1),
#  (b'[K] MgII forest and re-check FeII', 1),
#  (b'KLC now 1; RAS 2; Rob is right; KLC now 2', 1),
#  (b'[K] weak FeII blend 1550', 1),
#  (b'KLC now 0; JMO 2; let neighbor represent; KLC now 1', 1),
#  (b'[J] real abs to left?', 1),
#  (b'KLC was 0; JMO 2; match neighbor; KLC now 2', 1),
#  (b'[K] bad conti; check (was RTG=0)', 1),
#  (b'[J] 1548 is MgII 2800', 1),
#  (b'BAL on either side', 1),
#  (b'[K] ghost emission;', 1),
#  (b"What?? FeLoBAL?; KLC was 2; RAS 1; crazy doesn't matter; KLC now 1", 1),
#  (b'[K] bad conti; FeII 1608 blend 1548; check; 1550 is 1548 (was RTG=3)', 1),
#  (b'[K] SiII 1808 blend/is 1550; check', 1),
#  (b'[K] CII?; AlII', 1),
#  (b'[K] FeII blend 1550; System has CaII; check (was RTG=3)', 1),
#  (b'I think this is CII at 2.21', 1),
#  (b'This is SiIV at 2.05', 1),
#  (b'No HI here.', 1),
#  (b'This is SiIV (see the strong CIV)', 1),
#  (b'This looks like MgII to me', 1),
#  (b'KLC was 0; RAS 3; let neighbor represent; KLC 1', 1),
#  (b'Nothig else it could be.  Intrinsic?', 1),
#  (b'[K] check (was RTG=0); KLC was 1; RAS 2; let neighbmore represent; KLC still 1',
#   1),
#  (b'the right component is SiIV with the line on left', 1),
#  (b'This is CII associated with the intrinsic CIV.', 1),
#  (b'Left component is CII assocated with a DLA', 1),
#  (b'KL\xc7 was 0; RAS 2; let neighbor represent; KLC now 1', 1),
#  (b'I think this is MgII', 1),
#  (b'No, left is FeII 2374 for sure.', 1),
#  (b'Nice HI with it.', 1),
#  (b"Can't ID anything else...", 1),
#  (b'[K] Broad line should have a third candidate', 1),
#  (b"dn't see anything else", 1),
#  (b'[K] bad conti; FeII', 1),
#  (b'Right hand mixed with FeII 2344?', 1),
#  (b'SiIV 1393 at 3.022', 1),
#  (b'FeII 1608 from large DLA at z=1.57', 1),
#  (b'I *think* this is part of a MgII ocmplex at z=1.8', 1),
#  (b'I prefer MgII', 1),
#  (b"HI is not very aligned, but can't ID anything else.; KLC was 0; RAS 2; let neighbor represent; KLC now 1",
#   1),
#  (b"HI is not very aligned, but can't ID anything else.", 1),
#  (b'DLA ~ 1000 km/s to the blue with weak CIV', 1),
#  (b'SiIV proximate system', 1),
#  (b"Don't like the ratio, but no other obvious choices", 1),
#  (b'[K] ghost emission; broad line should be candidate (real)', 1),
#  (b'[K] CIV b1548 blends 1550', 1),
#  (b'Looks ratty, but MgII is compellng', 1),
#  (b'[K] SiIV 1393, FeII 1608 blend 1548; check (was RTG=3)', 1),
#  (b'[K] Broad blue line should be another candidate', 1),
#  (b'Left component is 1526 from stronger system.', 1),
#  (b'SiIV from the intrinsic system', 1),
#  (b'SIIV instrisic', 1),
#  ...]
